# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %% [markdown]
# # Load Files

# %%
pd.read_csv('Transporte_Publico_Espana.csv', delimiter=',')
# Out:
#         ID_Viaje                Fecha                Ruta  Numero_Pasajeros  \
# 0              1  2023-01-01 00:00:00  Barcelona - Bilbao               NaN
# 1              2  2023-01-01 00:01:00    Malaga - Sevilla              99.0
# 2              3  2023-01-01 00:02:00   Madrid - Zaragoza              10.0
# 3              4  2023-01-01 00:03:00    Sevilla - Madrid              96.0
# 4              5  2023-01-01 00:04:00     Madrid - Malaga              22.0
# ...          ...                  ...                 ...               ...
# 100095        96  2023-01-01 01:35:00    Sevilla - Madrid              85.0
# 100096        97  2023-01-01 01:36:00  Barcelona - Bilbao              65.0
# 100097        98  2023-01-01 01:37:00    Malaga - Sevilla              65.0
# 100098        99  2023-01-01 01:38:00  Madrid - Barcelona              41.0
# 100099       100  2023-01-01 01:39:00  Madrid - Barcelona              42.0
#
# ...
